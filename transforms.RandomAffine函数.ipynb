# %%
from PIL import Image
import torchvision.transforms as transforms

# %%
transfrom = transforms.RandomAffine(90)

# %%
img = Image.open(r"/data/bitt/wzq/wzq/python-deep-learning/data/cats_and_dogs_small/train/cats/cat.0.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x374 at 0x7EFE3F0F0128>

# %%
transfrom(img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x374 at 0x7EFE3F072BE0>

# %%
transfrom = transforms.RandomAffine(0, translate=(0, 0.2))

# %%
transfrom(img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x374 at 0x7FD2E8A85198>

# %%
transfrom = transforms.RandomAffine(0, scale=(0.8, 1.2))

# %%
transfrom(img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x374 at 0x7F0B82969160>

# %%
transfrom = transforms.RandomAffine(0, shear=(-20, 20), resample=Image.NEAREST)
print(transfrom)
# Out:
# RandomAffine(degrees=(0, 0), shear=(-20, 20))

# %%
transfrom(img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x374 at 0x7F0B82969630>
